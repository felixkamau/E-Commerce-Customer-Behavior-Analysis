# %%
import pandas as pd

# %%
df  = pd.read_csv('e-comm/E-commerce Customer Behavior - Sheet1.csv')
df
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 1            102    Male   34    Los Angeles          Silver       780.50
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# ..           ...     ...  ...            ...             ...          ...
# 345          446    Male   32          Miami          Silver       660.30
# 346          447  Female   36        Houston          Bronze       470.50
# 347          448  Female   30       New York            Gold      1190.80
# 348          449    Male   34    Los Angeles          Silver       780.20
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %% [markdown]
# ## Descriptive Statistics:

# %%
summary_stats = df.describe()
df.describe()
# Out:
#        Customer ID         Age  Total Spend  Items Purchased  Average Rating  \
# count   350.000000  350.000000   350.000000       350.000000      350.000000
# mean    275.500000   33.597143   845.381714        12.600000        4.019143
# std     101.180532    4.870882   362.058695         4.155984        0.580539
# min     101.000000   26.000000   410.800000         7.000000        3.000000
# 25%     188.250000   30.000000   502.000000         9.000000        3.500000
# 50%     275.500000   32.500000   775.200000        12.000000        4.100000
# 75%     362.750000   37.000000  1160.600000        15.000000        4.500000
# max     450.000000   43.000000  1520.100000        21.000000        4.900000
#
#        Days Since Last Purchase
# count                350.000000
# mean                  26.588571
# std                   13.440813
# min                    9.000000
# 25%                   15.000000
# 50%                   23.000000
# 75%                   38.000000
# ...

# %%
# Explore the distrubution  of the category variables
df['Gender'].value_counts()
# Out:
# Gender
# Female    175
# Male      175
# Name: count, dtype: int64

# %%
# City distribution
df['City'].value_counts()
# Out:
# City
# New York         59
# Los Angeles      59
# Chicago          58
# San Francisco    58
# Miami            58
# Houston          58
# Name: count, dtype: int64

# %%
df['Membership Type'].value_counts()
# Out:
# Membership Type
# Gold      117
# Silver    117
# Bronze    116
# Name: count, dtype: int64

# %%
# Satisfaction distribution
df['Satisfaction Level'].value_counts()
# Out:
# Satisfaction Level
# Satisfied      125
# Unsatisfied    116
# Neutral        107
# Name: count, dtype: int64

# %% [markdown]
# ## Segementation Analysis

# %%
# Segement customers based on varibales
segment_data = df.groupby(['Gender','Age','City','Membership Type']).agg({
    'Total Spend': 'sum',
    'Items Purchased': 'sum',
    'Average Rating': 'mean',
}).reset_index()

# %%
segment_data
# Out:
#     Gender  Age           City Membership Type  Total Spend  Items Purchased  \
# 0   Female   29          Miami          Silver       730.40               14
# 1   Female   29       New York            Gold      1120.20               14
# 2   Female   30       New York            Gold     28539.20              384
# 3   Female   31       New York            Gold     27404.40              360
# 4   Female   32       New York            Gold     10462.70              126
# 5   Female   35        Houston          Bronze       450.60                7
# 6   Female   36        Houston          Bronze     11102.00              191
# 7   Female   37        Houston          Bronze     10369.20              169
# 8   Female   38        Houston          Bronze      3998.10               72
# 9   Female   41        Chicago          Bronze     11626.00              217
# 10  Female   42        Chicago          Bronze      4668.45               82
# ...

# %% [markdown]
# ## Correlation analysis

# %%
# Caculate the  correlation matrix
# TODO data = df[[]]

# %% [markdown]
# ## Discount Impact Analysis

# %%
impact = df.groupby(['Discount Applied']).agg({
    'Total Spend':'mean',
    'Items Purchased':'mean'
}).reset_index()
impact
# Out:
#    Discount Applied  Total Spend  Items Purchased
# 0             False   903.489714        13.074286
# 1              True   787.273714        12.125714

# %%
# # Map the satsfaction lve to numerivcal value inorder to use mean
# satisfaction_mapping = {'Satisfied':1,'Neutral':2,'Unsatisfied':3}
# df['Satisfaction Level'] = df['Satisfaction Level'].map(satisfaction_mapping)

# # The relationship btwn   the days since last purchase and customer satisfaction
# day_since_last = df.groupby(['Days Since Last Purchase']).agg({
#     'Satisfaction Level':'sum',
# }).reset_index()
